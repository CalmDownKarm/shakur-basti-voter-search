# %%
import scattertext as st
from pprint import pprint

# %%
import spacy
import pandas as pd
from nltk import ngrams
nlp = spacy.load('en_core_web_lg')

# %%
# %load_ext autoreload
# %autoreload 2
import preprocess
from collections import Counter

# %%
# def get_scattertext_scores(df):
#     corpus = st.CorpusFromPandas(df, category_col='Class', text_col = 'Phrase', nlp=nlp).build()
#     print(list(corpus.get_scaled_f_scores_vs_background().index[:10]))
#     term_freq_df = corpus.get_term_freq_df()
#     term_freq_df['Democratic Score'] = corpus.get_scaled_f_scores('Hatespeech')
#     pprint(list(term_freq_df.sort_values(by='Democratic Score', ascending=False).index[:50]))

# %%
new_stop = nlp.Defaults.stop_words.union({'xxuser', 'xxurl'})
def fix_tokens(tokens):
    special_tokens = {'xxmaj', 'xxup'}
    special_indexes = [i for i,tok in enumerate(tokens) if tok in special_tokens]
    for i in special_indexes:
        if i+1 < len(tokens):
            tokens[i+1] = tokens[i+1].capitalize() if tokens[i] == 'xxmaj' else tokens[i+1].upper()
    return [token for token in tokens if token.lower() not in special_tokens]
def get_cues(df, colname, classes, prod=False):
    '''colname is name of the text colum, classes is name of labels'''
    if prod:
        df = df[df['pred_labels'] == df['true_labels']]
    df['tokens'] =preprocess.preprocess(df[colname])
    df['tokens'] = df['tokens'].apply(lambda x: fix_tokens([token for token in x if token not in new_stop]))
#     df['tokens'] = df['tokens'].apply(fix_tokens)
    df['bigrams'] = df.tokens.apply(lambda x: list(ngrams(x,2)))
    df['trigrams'] = df.tokens.apply(lambda x: list(ngrams(x,3)))
    df['bigrams'] = df.bigrams.apply(lambda x: [' '.join(k) for k in x])
    df['trigrams'] = df.trigrams.apply(lambda x: [' '.join(k) for k in x])
    counters = {}
    for _class, group in df.groupby(classes):
        counters[_class] = Counter()
        for ngram in ['tokens', 'bigrams', 'trigrams']:
            group[ngram].apply(lambda x: counters[_class].update(set(x)))
    all_cues = pd.DataFrame(counters)
#     for key, val in df.groupby(classes).count()[colname].to_dict().items():
#         all_cues[key] /= val
    common_cues = all_cues.dropna()
    h_cues = all_cues[all_cues['Hatespeech'].notnull() & all_cues['Normal'].isnull() & all_cues['Trolling'].isnull()]
    t_cues = all_cues[all_cues['Trolling'].notnull() & all_cues['Normal'].isnull() & all_cues['Hatespeech'].isnull()]
    n_cues = all_cues[all_cues['Normal'].notnull() & all_cues['Trolling'].isnull() & all_cues['Hatespeech'].isnull()]
    return all_cues, h_cues, t_cues, n_cues

# %%
df = pd.read_excel('./final_data_files/cleaned_total_data_hopefully.xlsx')
# all_cues, h_cues, t_cues, n_cues = get_cues(df, 'Phrase', 'Class')

# %%
bertPreds = pd.read_json('BertTestPreds.json')

# %%
bertPreds.sentence = bertPreds.sentence.apply(lambda x: eval(x)[0])

# %%
bertPreds.head()
# Out:
#                                             sentence true_labels pred_labels
# 0  xxuserrickygervais BORING&amp;HACK allah and m...  Hatespeech  Hatespeech
# 1  Brands, don't sabotage your #customers' experi...      Normal      Normal
# 2  Apple iPhone 5 Unlocked GSM 16GB White Smartph...      Normal      Normal
# 3  GO FUCK YOURSELF BITCH.  I HATE YOUR SOULD.  M...  Hatespeech  Hatespeech
# 4                    xxuserDolanGang beans u beaner?  Hatespeech  Hatespeech

# %%
pall_cues, ph_cues, pt_cues, pn_cues = get_cues(bertPreds, 'sentence', 'pred_labels', prod=True)

# %%
ph_cues.columns = ['pred'+ col for col in ph_cues.columns.values]
prod_h = pd.concat([h_cues, ph_cues], axis=1, sort=False)

# %%
prod_h
# Out:
#                          Hatespeech  Normal  Trolling  mean  predHatespeech  \
# INTERESTED                      1.0     NaN       NaN   1.0             NaN
# hustling                        1.0     NaN       NaN   1.0             NaN
# DISGRACEFUL                     1.0     NaN       NaN   1.0             NaN
# Department                      1.0     NaN       NaN   1.0             NaN
# Justice                         1.0     NaN       NaN   1.0             1.0
# ...                             ...     ...       ...   ...             ...
# ! \n \n  jãcskãc                NaN     NaN       NaN   NaN             1.0
# jãcskãc Couriano stupid         NaN     NaN       NaN   NaN             1.0
# 4 ! jãcskãc                     NaN     NaN       NaN   NaN             1.0
# ! jãcskãc Couriano              NaN     NaN       NaN   NaN             1.0
# \n \n  jãcskãc Couriano         NaN     NaN       NaN   NaN             1.0
#
# ...

# %%
prod_h = prod_h.rename(columns={'Hatespeech': 'Applicability', 'predHatespeech':'Productivity'}).drop(['Normal', 'Trolling', 'mean', 'predNormal', 'predTrolling', 'predmean'], axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-255-caba0802a7cd> in <module>
# ----> 1 prod_h = prod_h.rename(columns={'Hatespeech': 'Applicability', 'predHatespeech':'Productivity'}).drop(['Normal', 'Trolling', 'mean', 'predNormal', 'predTrolling', 'predmean'], axis=1)
#
# ~/anaconda3/envs/analytics/lib/python3.7/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4095             level=level,
#    4096             inplace=inplace,
# -> 4097             errors=errors,
#    4098         )
#    4099
#
# ~/anaconda3/envs/analytics/lib/python3.7/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3913         for axis, labels in axes.items():
#    3914             if labels is not None:
# ...

# %%
prod_h = prod_h.rename(columns={'Hatespeech': 'Applicability', 'predHatespeech':'Productivity'}).drop(['Normal', 'Trolling', 'mean', 'predNormal', 'predTrolling', 'predmean'], axis=1)
prod_h['Productivity'] /= prod_h['Applicability']

# %%
prod_h['mean'] = prod_h.mean(axis=1)

# %%
prod_h.sort_values('Productivity', ascending=False)
# Out:
#                                     Applicability  Productivity  mean
# honor                                         1.0           2.0   1.5
# ! \n \n  u                                    2.0           1.0   1.5
# WTF UR PROMBLEM                               2.0           1.0   1.5
# faggot ass mutha                              2.0           1.0   1.5
# PROMBLEM u GAY                                2.0           1.0   1.5
# ...                                           ...           ...   ...
# " xxusercb_baby24 :                           NaN           NaN   NaN
# xxuserdevilgrimz : xxuservigxrarts            NaN           NaN   NaN
# xxuservigxrarts fucking gay                   NaN           NaN   NaN
# " xxuserdevilgrimz :                          NaN           NaN   NaN
# : xxuservigxrarts fucking                     NaN           NaN   NaN
#
# [53769 rows x 3 columns]

# %%
def pick_values(df, num):
    df = df.sort_values('Productivity').dropna()
    topN = df[:num]
    bottomN = df[-num:]
#     randomN = df.sample(num)
    return pd.concat([topN, bottomN], sort=False)

# %%
k = prod_h.sample(30)

# %%
import numpy as np

from bokeh.models import ColumnDataSource, Plot, LinearAxis, Grid
from bokeh.models.glyphs import Text
from bokeh.io import curdoc, show

source = ColumnDataSource(k)

plot = Plot(
    title=None, plot_width=600, plot_height=600,
    min_border=0, toolbar_location=None)

glyph = Text(x="Productivity", y="Applicability", text="index", angle=0, text_color="#000000", text_alpha=0.5)
plot.add_glyph(source, glyph)

xaxis = LinearAxis()
plot.add_layout(xaxis, 'below')

yaxis = LinearAxis()
plot.add_layout(yaxis, 'left')

plot.add_layout(Grid(dimension=0, ticker=xaxis.ticker))
plot.add_layout(Grid(dimension=1, ticker=yaxis.ticker))

curdoc().add_root(plot)

show(plot)

# %%
prod_h
# Out:
#                          Hatespeech  Normal  Trolling  mean  predHatespeech  \
# INTERESTED                      1.0     NaN       NaN   1.0             NaN
# hustling                        1.0     NaN       NaN   1.0             NaN
# DISGRACEFUL                     1.0     NaN       NaN   1.0             NaN
# Department                      1.0     NaN       NaN   1.0             NaN
# Justice                         1.0     NaN       NaN   1.0             1.0
# ...                             ...     ...       ...   ...             ...
# ! \n \n  jãcskãc                NaN     NaN       NaN   NaN             1.0
# jãcskãc Couriano stupid         NaN     NaN       NaN   NaN             1.0
# 4 ! jãcskãc                     NaN     NaN       NaN   NaN             1.0
# ! jãcskãc Couriano              NaN     NaN       NaN   NaN             1.0
# \n \n  jãcskãc Couriano         NaN     NaN       NaN   NaN             1.0
#
# ...

# %%
from bokeh.plotting import figure, show, output_notebook
from bokeh.models import ColumnDataSource, Range1d, LabelSet, Label

output_file("label.html", title="label.py example")

source = ColumnDataSource(prod_h)

p = figure(title='Dist. of 10th Grade Students at Lee High')
p.scatter(x='Productivity', y='Applicability', size=6, source=source)
p.xaxis[0].axis_label = 'Weight (lbs)'
p.yaxis[0].axis_label = 'Height (in)'

# labels = LabelSet(x='Productivity', y='Applicability', text='index', level='glyph',
#               x_offset=1, y_offset=1, source=source, render_mode='canvas', text_alpha=1, angle=1)

# citation = Label(x=70, y=70, x_units='screen', y_units='screen',
#                  text='Collected by Luke C. 2016-04-01', render_mode='css',
#                  border_line_color='black', border_line_alpha=1.0,
#                  background_fill_color='white', background_fill_alpha=1.0)

# p.add_layout(labels)
# p.add_layout(citation)

show(p)
# Out:
# ERROR:bokeh.core.validation.check:E-1001 (BAD_COLUMN_NAME): Glyph refers to nonexistent column name. This could either be due to a misspelling or typo, or due to an expected column being missing. : key "x" value "Productivity", key "y" value "Applicability" [renderer: GlyphRenderer(id='7882', ...)]

# %%
k = prod_h.dropna().sort_values('Applicability', ascending=False)[:30]

# %%
k
# Out:
#                   Applicability  Productivity       mean
# ? \n \n                    54.0      0.277778  27.138889
# piece shit                 47.0      0.276596  23.638298
# Wikipedia                  46.0      0.260870  23.130435
# wikipedia                  44.0      0.204545  22.102273
# ! \n                       43.0      0.348837  21.674419
# KILL                       43.0      0.186047  21.593023
# \n \n  Fuck                42.0      0.071429  21.035714
# faggot .                   41.0      0.268293  20.634146
# DIE                        41.0      0.292683  20.646341
# NIGGER                     39.0      0.256410  19.628205
# FAGGOT                     38.0      0.289474  19.144737
# \n \n  XXUP                37.0      0.270270  18.635135
# white trash                37.0      0.297297  18.648649
# delete                     36.0      0.305556  18.152778
# raped                      34.0      0.235294  17.117647
# ...

# %%
tdav = pd.read_json('/home/karmanya/Downloads/T_DavidsonBertTestPreds.json')

# %%
maps = {'Hatespeech': 'Hatespeech', 'Neither': 'Normal', 'Offensive': 'Trolling'}

# %%
tdav.sentence = tdav.sentence.apply(lambda x: eval(x)[0])

# %%
tdav['true_labels']=tdav.true_labels.map(maps)

# %%
tdav['pred_labels'] = tdav.pred_labels.map(maps)

# %%
all_cues, h_cues, t_cues, n_cues = get_cues(tdav, 'sentence', 'true_labels')
pall_cues, ph_cues, pt_cues, pn_cues = get_cues(tdav, 'sentence', 'pred_labels', prod=True)

# %%
ph_cues.columns = ['pred'+ col for col in ph_cues.columns.values]
prod_h = pd.concat([h_cues, ph_cues], axis=1, sort=False)

# %%
h_cues.sort_values
# Out:
#                      Hatespeech  Normal  Trolling  mean
# INTERESTED                  1.0     NaN       NaN   1.0
# hustling                    1.0     NaN       NaN   1.0
# DISGRACEFUL                 1.0     NaN       NaN   1.0
# Department                  1.0     NaN       NaN   1.0
# Justice                     1.0     NaN       NaN   1.0
# ...                         ...     ...       ...   ...
# ass spic hop                1.0     NaN       NaN   1.0
# little nigga ,              1.0     NaN       NaN   1.0
# hop faggot ass              1.0     NaN       NaN   1.0
# border little nigga         1.0     NaN       NaN   1.0
# beaner ass spic             1.0     NaN       NaN   1.0
#
# [6318 rows x 4 columns]

# %%
prod_h = prod_h.rename(columns={'Hatespeech': 'Applicability', 'predHatespeech':'Productivity'}).drop(['Normal', 'Trolling', 'mean', 'predNormal', 'predTrolling', 'predmean'], axis=1)
prod_h['Productivity'] /= prod_h['Applicability']

# %%
prod_h.dropna().sort_values('Productivity', ascending=False)
# Out:
#                     Applicability  Productivity
# Nigger                        1.0      1.000000
# George michael fag            1.0      1.000000
# ' James x                     1.0      1.000000
# trash cultist .               1.0      1.000000
# x ' white                     1.0      1.000000
# ...                           ...           ...
# xxusergezus                   2.0      0.500000
# Jew                           2.0      0.500000
# # faggot                      2.0      0.500000
# # Virginia                    2.0      0.500000
# , stupid                      3.0      0.333333
#
# [1098 rows x 2 columns]

# %%
colormap = {'setosa': 'red', 'versicolor': 'green', 'virginica': 'blue'}
colors = [colormap[x] for x in flowers['species']]

# %%
ls
# Out:
# 'Dataset EDA.ipynb'   Hatebase.ipynb   model_inferences/   README.md
#  final_data_files/    labeled_data.p   preprocess.py       shuffle_labels.ipynb
#  hatebase_all.json    label.html       __pycache__/        Untitled-Copy1.ipynb

# %%
# !mv /home/karmanya/Downloads/BertTestPreds.json ./

# %%
ls
# Out:
#  BertTestPreds.json   labeled_data.p      README.md
# 'Dataset EDA.ipynb'   label.html          shuffle_labels.ipynb
#  final_data_files/    model_inferences/   Untitled-Copy1.ipynb
#  hatebase_all.json    preprocess.py
#  Hatebase.ipynb       __pycache__/

# %%
g = pd.concat(prods[1:], sort=False)

# %%
from bokeh.plotting import figure, show, output_file
from bokeh.sampledata.iris import flowers

colormap = {'Hatespeech': 'red', 'Trolling': 'green', 'Normal': 'blue'}
colors = [colormap[x] for x in g['Class']]

p = figure(title = "Productivity vs Applicability")
p.xaxis.axis_label = 'Productivity'
p.yaxis.axis_label = 'Applicability'
p.y_range=Range1d(0, 36)
p.circle(g["Productivity"], g["Applicability"],
         color=colors, fill_alpha=0.2, size=5)

output_file("iris.html", title="iris.py example")

show(p)

# %%
g.sort_values('Applicability', ascending=False)
# Out:
#                             Applicability  Productivity       Class
# kill                                 35.0      0.800000  Hatespeech
# page                                 22.0      0.909091  Hatespeech
# Look like                            16.0      0.812500    Trolling
# Wikipedia                            14.0      0.857143  Hatespeech
# white trash                          14.0      0.785714  Hatespeech
# ...                                   ...           ...         ...
# article short sick                    1.0      1.000000  Hatespeech
# vandals Quit Wikipedia                1.0      1.000000  Hatespeech
# pleasure watching tortured            1.0      1.000000  Hatespeech
# short sick Start                      1.0      1.000000  Hatespeech
# , mac figured                         1.0      1.000000      Normal
#
# [29218 rows x 3 columns]

# %%
def get_prods(df):
    prods = []
    for app, prod, class_ in zip(get_cues(df, 'sentence', 'true_labels'), get_cues(df, 'sentence', 'pred_labels', prod=True), ['All', 'Hatespeech', 'Trolling', 'Normal']):
        prod = pd.concat([app, prod], axis=1, sort=False)
        prod.dropna(axis=1, how='all', inplace=True)
        if class_!= 'All':
            prod.columns = ['Applicability', 'Productivity']
            prod.dropna(axis=0, inplace=True, subset=['Applicability', 'Productivity'])
            prod['Productivity'] /= prod['Applicability']
            prod['Class'] = class_
            prod['Coverage'] = prod['Applicability']/prod.shape[0]
            prod['mult'] = prod['Coverage'] * prod['Productivity']
            prods.append(prod)
    return prods

# %%
our_data.drop('index', axis=1, inplace=True)

# %%
import re
pattern = re.compile(r'(xxuser[A-Z])\w+', re.I)

# %%
our_data['sentence'] = our_data['sentence'].apply(lambda x: pattern.sub('xxuser', x))

# %%
prods = get_prods(our_data)
cues = pd.concat(prods, sort=False)
# Out:
# /home/karmanya/anaconda3/envs/analytics/lib/python3.7/site-packages/ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   del sys.path[0]
# /home/karmanya/anaconda3/envs/analytics/lib/python3.7/site-packages/ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /home/karmanya/anaconda3/envs/analytics/lib/python3.7/site-packages/ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
import seaborn as sns
gg = cues.sort_values('mult', ascending=False)[:cues.shape[0]//4]
sns.countplot(gg.Class)

# %%
our_data = pd.read_json('BertTestPreds.json')

# %%
our_data['sentence'] = our_data.sentence.apply(lambda x: eval(x)[0])

# %%
all_cues = get_cues(our_data, 'sentence', 'true_labels')[0]

# %%
# Out:
#            Hatespeech  Normal  Trolling
# God               8.0     4.0       1.0
# ?                72.0    52.0      65.0
# away              4.0     1.0       5.0
# ,               179.0   109.0      92.0
# FUCKING          15.0     7.0       3.0
# ...               ...     ...       ...
# _ :               1.0     1.0       2.0
# , guys            1.0     1.0       1.0
# ! ! !            24.0     6.0       8.0
# ? ? ?             1.0     2.0       1.0
# xxrep 4 !        14.0     1.0       1.0
#
# [412 rows x 3 columns]

# %%
import seaborn as sns
sns.countplot(prods['Class'])

# %% [markdown]
# # token counting

# %%
ls final_data_files/
# Out:
# 20pctshuffletdav.xlsx
# 20pctshuffle.xlsx
# cleaned_total_data_hopefully.xlsx
# hatespeech.xlsx
# Normal_from_crowdsource_includes_profanity.xlsx
# normal_from_profanity_from_sources.xlsx
# trolling_from_normal_crowdsource.xlsx
# trolling_from_reddit.xlsx
# trolling_from_t_davidson.xlsx

# %%
df = pd.read_excel("final_data_files/cleaned_total_data_hopefully.xlsx")

# %%
df.head()
# Out:
#    Unnamed: 0                                             Phrase     Class
# 0           0  @_C_Parris69_ your picture makes you look like...  Trolling
# 1           1  @_SoulSurvivor_ @zakbauer I dont have any prob...  Trolling
# 2           2  @_TurnDownDre @Jordan__Grimes @kushdaddycorr @...  Trolling
# 3           3  @amandabynes i can give you some of my clothes...  Trolling
# 4           4                 @ashhruggiero happy birthday queer  Trolling

# %%
# Out:
#             Unnamed: 0    lens
# Class
# Hatespeech     7306621  127143
# Normal         7620850   44534
# Trolling       2210114   34223

# %%
df['Processed_phrase'] = preprocess.preprocess(df.Phrase.values)

# %%
df['lens'] = df['Processed_phrase'].apply(len)
df.mean()
# Out:
# Unnamed: 0    2927.00000
# lens            35.89462
# dtype: float64

# %%
df.sort_values('lens').head(10)
# Out:
#       Unnamed: 0                      Phrase     Class       Processed_phrase  \
# 513          513                        ass.  Trolling                  [ass]
# 5670        5670                <b>#fuck</b>    Normal                 [fuck]
# 1091        1091                      phrase  Trolling               [phrase]
# 177          177                       damn.  Trolling                 [damn]
# 1504        1504               damn straight  Trolling       [damn, straight]
# 1047        1047                    fuck you  Trolling            [fuck, you]
# 128          128                     gay man  Trolling             [gay, man]
# 4995        4995  <b>fucking</b> unpleasant.    Normal  [fucking, unpleasant]
# 223          223                       nerd!  Trolling              [nerd, !]
# 1677        1677            attention whore.  Trolling     [attention, whore]
#
#       lens
# 513      1
# 5670     1
# 1091     1
# 177      1
# 1504     2
# 1047     2
# 128      2
# ...

# %%
df['Processed_phrase'] = df['Processed_phrase'].apply(lambda span :' '.join(span))

# %%
df['tokens'] = df['Processed_phrase'].apply(nlp)

# %%
df['lens'] = df['tokens'].apply(len)
df.groupby('Class').sum()
# Out:
#             Unnamed: 0    lens
# Class
# Hatespeech     7306621  132617
# Normal         7620850   43168
# Trolling       2210114   35242

# %%
df.groupby('Class').sum().sum()
# Out:
# Unnamed: 0    17137585
# lens            211027
# dtype: int64

# %%
from spacy.attrs import ORTH
df['types'] = df['tokens'].apply(lambda doc: doc.count_by(ORTH))

# %%
from collections import Counter
# counters = {}
# for Class, Frame in df.groupby('Class'):
#     counters[Class] = Counter()
#     for item in Frame.types.values:
#         counters[Class].update(item)

# %%
len(counters['Hatespeech'].items())
# Out:
# 7025

# %%
len(counters['Normal'].items())
# Out:
# 6915

# %%
len(counters['Trolling'].items())
# Out:
# 5101

# %%
df.groupby('Class').count().sum()
# Out:
# Unnamed: 0          5855
# Phrase              5855
# tokens              5855
# lens                5855
# types               5855
# Processed_phrase    5855
# dtype: int64

# %%
7025+6915+5101
# Out:
# 19041

# %%
132617+43168+35242
# Out:
# 211027

# %%
df['ents'] = df['tokens'].apply(lambda x: list(x.ents))

# %%
POS_counter = Counter()
df['tokens'].apply(lambda doc: POS_counter.update([token.pos_ for token in doc]))
# Out:
# 0       None
# 1       None
# 2       None
# 3       None
# 4       None
#         ...
# 5850    None
# 5851    None
# 5852    None
# 5853    None
# 5854    None
# Name: tokens, Length: 5855, dtype: object

# %%
counters = {}
for Class, Frame in df.groupby('Class'):
    counters[Class] = Counter()
    for item in Frame.tokens.values:
        counters[Class].update([token.pos_ for token in item])

# %%
df['aux'] = df['tokens'].apply(lambda x: [token for token in x if token.pos_=='AUX'])

# %%
df['l_'] = df['aux'].apply(len)

# %%
df[df['l_']!=0]
# Out:
#       Unnamed: 0                                             Phrase  \
# 1058        1058  Seriously though, it was an inspiring wedding....
# 1443        1443  YOU STUPID WHORE I HOPE YOU ARE IN YOUR HOUSE ...
# 1919        1919  RT @SmolTolLarry: WHO DID THIS? I'M FUCKING DO...
# 1924        1924  That was an ugly ass game but I'LL FUCKIN TAKE...
# 2855        2855  WOULDN'T BE THE FIRST TIME BITCH. FUCK YOU I'L...
# 2992        2992  ifÂ \n\nIF YOU HAD ANY GUTS YOU'D BAN ME RIGHT...
# 3177        3177  HAHAHAHAHAHAHAHA YOU CAN'T STOP ME FUCKING HOM...
# 3220        3220  YOU FUCKERS THINK YOU CAN STOP ME, YOU REALLY ...
# 3245        3245                              I'LL KILL YOU ALL!!!!
# 3271        3271  cheSTOP ADDING IN SHIT ONLY TO SUPPORT YOUR FU...
# 3280        3280  YO\nWHY CANT I MESS UP UR SITE\nNO SCHOOLS R A...
# 3350        3350  I KNOW IT'S ENGLAND BECAUSE IT SAYS UTCÂ \n\nI...
# 3421        3421  AWWW MAH GAWD LOIK DIS MOVY GETS ME SOOOO MOIS...
# ...

# %%
pd.DataFrame(counters).sort_values(['Hatespeech', 'Normal', 'Trolling'], ascending=False)
# Out:
#        Hatespeech  Normal  Trolling
# VERB        38997    7490      7065
# NOUN        34607   12019      7454
# PRON        11911    2683      3563
# ADJ          8918    3390      2497
# PUNCT        8712    3799      3007
# DET          7613    3193      3472
# ADP          5389    2941      2678
# ADV          4285    2344      2324
# CCONJ        2401     858       714
# PART         2337     869       763
# PROPN        2065     363       129
# NUM          2028    1268       544
# X            1693     941       286
# INTJ         1369     867       703
# SYM           250     137        38
# SPACE          23       4         3
# AUX            19       2         2
